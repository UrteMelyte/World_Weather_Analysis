# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 756

# %%
import requests
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = str(city_weather["weather"][0]["description"])
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hilo
# Processing Record 2 of Set 1 | vanimo
# Processing Record 3 of Set 1 | kimbe
# Processing Record 4 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 1 | ruidoso
# Processing Record 6 of Set 1 | qaanaaq
# Processing Record 7 of Set 1 | luderitz
# Processing Record 8 of Set 1 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 9 of Set 1 | bethel
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | coquimbo
# Processing Record 12 of Set 1 | kaeo
# Processing Record 13 of Set 1 | atambua
# Processing Record 14 of Set 1 | naryan-mar
# Processing Record 15 of Set 1 | narsaq
# Processing Record 16 of Set 1 | saldanha
# Processing Record 17 of Set 1 | bluff
# Processing Record 18 of Set 1 | mataura
# Processing Record 19 of Set 1 | kavieng
# Processing Record 20 of Set 1 | ushirombo
# Processing Record 21 of Set 1 | flinders
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | nikolskoye
# Processing Record 24 of Set 1 | albany
# Processing Record 25 of Set 1 | hermanus
# Processing Record 26 of Set 1 | norman wells
# Processing Record 27 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 1 | vaini
# Processing Record 29 of Set 1 | ostrovnoy
# Processing Record 30 of Set 1 | carutapera
# Processing Record 31 of Set 1 | suez
# Processing Record 32 of Set 1 | tasiilaq
# Processing Record 33 of Set 1 | tuktoyaktuk
# Processing Record 34 of Set 1 | mocambique
# City not found. Skipping...
# Processing Record 35 of Set 1 | hithadhoo
# Processing Record 36 of Set 1 | mandalgovi
# Processing Record 37 of Set 1 | puerto ayora
# Processing Record 38 of Set 1 | ayan
# Processing Record 39 of Set 1 | at-bashi
# Processing Record 40 of Set 1 | muli
# Processing Record 41 of Set 1 | new norfolk
# Processing Record 42 of Set 1 | mahebourg
# Processing Record 43 of Set 1 | cabo san lucas
# Processing Record 44 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 1 | rikitea
# Processing Record 46 of Set 1 | tazovskiy
# Processing Record 47 of Set 1 | khatanga
# Processing Record 48 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 1 | barrow
# Processing Record 50 of Set 1 | hobart
# Processing Record 1 of Set 2 | lac du bonnet
# Processing Record 2 of Set 2 | tiksi
# Processing Record 3 of Set 2 | atuona
# Processing Record 4 of Set 2 | georgetown
# Processing Record 5 of Set 2 | husavik
# Processing Record 6 of Set 2 | torbay
# Processing Record 7 of Set 2 | victoria
# Processing Record 8 of Set 2 | dikson
# Processing Record 9 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 2 | coihaique
# Processing Record 11 of Set 2 | pimentel
# Processing Record 12 of Set 2 | kasongo-lunda
# Processing Record 13 of Set 2 | salalah
# Processing Record 14 of Set 2 | kawalu
# Processing Record 15 of Set 2 | bardiyah
# Processing Record 16 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 17 of Set 2 | roncesvalles
# Processing Record 18 of Set 2 | niono
# Processing Record 19 of Set 2 | caravelas
# Processing Record 20 of Set 2 | saskylakh
# Processing Record 21 of Set 2 | avarua
# Processing Record 22 of Set 2 | nantucket
# Processing Record 23 of Set 2 | yellowknife
# Processing Record 24 of Set 2 | ituni
# City not found. Skipping...
# Processing Record 25 of Set 2 | nanortalik
# Processing Record 26 of Set 2 | lompoc
# Processing Record 27 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 2 | idaho falls
# Processing Record 29 of Set 2 | potam
# Processing Record 30 of Set 2 | great bend
# Processing Record 31 of Set 2 | buraydah
# Processing Record 32 of Set 2 | port hedland
# Processing Record 33 of Set 2 | vestmannaeyjar
# Processing Record 34 of Set 2 | shasta lake
# Processing Record 35 of Set 2 | harper
# Processing Record 36 of Set 2 | port elizabeth
# Processing Record 37 of Set 2 | shelton
# Processing Record 38 of Set 2 | javanrud
# Processing Record 39 of Set 2 | mao
# Processing Record 40 of Set 2 | pevek
# Processing Record 41 of Set 2 | olafsvik
# Processing Record 42 of Set 2 | ushuaia
# Processing Record 43 of Set 2 | bambous virieux
# Processing Record 44 of Set 2 | bentiu
# Processing Record 45 of Set 2 | masterton
# Processing Record 46 of Set 2 | umm kaddadah
# Processing Record 47 of Set 2 | kapaa
# Processing Record 48 of Set 2 | severo-kurilsk
# Processing Record 49 of Set 2 | council bluffs
# Processing Record 50 of Set 2 | tshikapa
# Processing Record 1 of Set 3 | tambun
# Processing Record 2 of Set 3 | castro
# Processing Record 3 of Set 3 | huarmey
# Processing Record 4 of Set 3 | launceston
# Processing Record 5 of Set 3 | thompson
# Processing Record 6 of Set 3 | carnarvon
# Processing Record 7 of Set 3 | sao joao da barra
# Processing Record 8 of Set 3 | northam
# Processing Record 9 of Set 3 | saint-augustin
# Processing Record 10 of Set 3 | sucila
# Processing Record 11 of Set 3 | provideniya
# Processing Record 12 of Set 3 | butaritari
# Processing Record 13 of Set 3 | dingle
# Processing Record 14 of Set 3 | tiarei
# Processing Record 15 of Set 3 | muros
# Processing Record 16 of Set 3 | port alfred
# Processing Record 17 of Set 3 | anadyr
# Processing Record 18 of Set 3 | boende
# Processing Record 19 of Set 3 | paamiut
# Processing Record 20 of Set 3 | porto franco
# Processing Record 21 of Set 3 | cape town
# Processing Record 22 of Set 3 | karangasem
# Processing Record 23 of Set 3 | pekan
# Processing Record 24 of Set 3 | berlevag
# Processing Record 25 of Set 3 | isla mujeres
# Processing Record 26 of Set 3 | ewa beach
# Processing Record 27 of Set 3 | manicore
# Processing Record 28 of Set 3 | pyra
# Processing Record 29 of Set 3 | prado
# Processing Record 30 of Set 3 | nioro
# Processing Record 31 of Set 3 | ulaanbaatar
# Processing Record 32 of Set 3 | greifswald
# Processing Record 33 of Set 3 | kano
# Processing Record 34 of Set 3 | kroya
# Processing Record 35 of Set 3 | zhigansk
# Processing Record 36 of Set 3 | segezha
# Processing Record 37 of Set 3 | hamilton
# Processing Record 38 of Set 3 | nalut
# Processing Record 39 of Set 3 | souillac
# Processing Record 40 of Set 3 | tual
# Processing Record 41 of Set 3 | le pradet
# Processing Record 42 of Set 3 | iquique
# Processing Record 43 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 44 of Set 3 | esperance
# Processing Record 45 of Set 3 | sembakung
# Processing Record 46 of Set 3 | suruc
# Processing Record 47 of Set 3 | pisco
# Processing Record 48 of Set 3 | samarai
# Processing Record 49 of Set 3 | port macquarie
# Processing Record 50 of Set 3 | bredasdorp
# Processing Record 1 of Set 4 | seminole
# Processing Record 2 of Set 4 | luang prabang
# Processing Record 3 of Set 4 | gusinoye ozero
# Processing Record 4 of Set 4 | padang
# Processing Record 5 of Set 4 | chuy
# Processing Record 6 of Set 4 | kaa-khem
# Processing Record 7 of Set 4 | hambantota
# Processing Record 8 of Set 4 | lavrentiya
# Processing Record 9 of Set 4 | brewster
# Processing Record 10 of Set 4 | isangel
# Processing Record 11 of Set 4 | vila franca do campo
# Processing Record 12 of Set 4 | likasi
# Processing Record 13 of Set 4 | lashio
# Processing Record 14 of Set 4 | newport
# Processing Record 15 of Set 4 | jamestown
# Processing Record 16 of Set 4 | saint-pierre
# Processing Record 17 of Set 4 | mynay
# Processing Record 18 of Set 4 | billings
# Processing Record 19 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 20 of Set 4 | panama city
# Processing Record 21 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 22 of Set 4 | crab hill
# City not found. Skipping...
# Processing Record 23 of Set 4 | cayenne
# Processing Record 24 of Set 4 | santa helena
# Processing Record 25 of Set 4 | la ronge
# Processing Record 26 of Set 4 | grindavik
# Processing Record 27 of Set 4 | okhotsk
# Processing Record 28 of Set 4 | arraial do cabo
# Processing Record 29 of Set 4 | mitsamiouli
# Processing Record 30 of Set 4 | khandbari
# Processing Record 31 of Set 4 | bosaso
# Processing Record 32 of Set 4 | namibe
# Processing Record 33 of Set 4 | yulara
# Processing Record 34 of Set 4 | bafra
# Processing Record 35 of Set 4 | repcelak
# Processing Record 36 of Set 4 | lata
# Processing Record 37 of Set 4 | beringovskiy
# Processing Record 38 of Set 4 | vostok
# Processing Record 39 of Set 4 | jardim
# Processing Record 40 of Set 4 | noumea
# Processing Record 41 of Set 4 | neryungri
# Processing Record 42 of Set 4 | ribeira grande
# Processing Record 43 of Set 4 | leningradskiy
# Processing Record 44 of Set 4 | usvyaty
# Processing Record 45 of Set 4 | klaksvik
# Processing Record 46 of Set 4 | la linea
# Processing Record 47 of Set 4 | pangkalanbuun
# Processing Record 48 of Set 4 | bo rai
# Processing Record 49 of Set 4 | port hardy
# Processing Record 50 of Set 4 | kununurra
# Processing Record 1 of Set 5 | mehamn
# Processing Record 2 of Set 5 | kodiak
# Processing Record 3 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 5 | mergui
# City not found. Skipping...
# Processing Record 5 of Set 5 | hinton
# Processing Record 6 of Set 5 | broken hill
# Processing Record 7 of Set 5 | kaoma
# Processing Record 8 of Set 5 | portland
# Processing Record 9 of Set 5 | ondorhaan
# City not found. Skipping...
# Processing Record 10 of Set 5 | san carlos de bariloche
# Processing Record 11 of Set 5 | laguna
# Processing Record 12 of Set 5 | lewisburg
# Processing Record 13 of Set 5 | ambon
# Processing Record 14 of Set 5 | porto de moz
# Processing Record 15 of Set 5 | lorengau
# Processing Record 16 of Set 5 | marawi
# Processing Record 17 of Set 5 | farafangana
# Processing Record 18 of Set 5 | ancud
# Processing Record 19 of Set 5 | kishiwada
# Processing Record 20 of Set 5 | rottenmann
# Processing Record 21 of Set 5 | pousat
# City not found. Skipping...
# Processing Record 22 of Set 5 | curaca
# Processing Record 23 of Set 5 | ondjiva
# Processing Record 24 of Set 5 | hindaun
# Processing Record 25 of Set 5 | ucluelet
# Processing Record 26 of Set 5 | airai
# Processing Record 27 of Set 5 | jalu
# Processing Record 28 of Set 5 | mackay
# Processing Record 29 of Set 5 | morondava
# Processing Record 30 of Set 5 | faya
# Processing Record 31 of Set 5 | normandin
# Processing Record 32 of Set 5 | mentok
# City not found. Skipping...
# Processing Record 33 of Set 5 | saint anthony
# Processing Record 34 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 35 of Set 5 | usakos
# Processing Record 36 of Set 5 | skalistyy
# City not found. Skipping...
# Processing Record 37 of Set 5 | komsomolskiy
# Processing Record 38 of Set 5 | bandarbeyla
# Processing Record 39 of Set 5 | ajdabiya
# Processing Record 40 of Set 5 | saint-philippe
# Processing Record 41 of Set 5 | chokurdakh
# Processing Record 42 of Set 5 | maumere
# Processing Record 43 of Set 5 | kieta
# Processing Record 44 of Set 5 | key west
# Processing Record 45 of Set 5 | inhambane
# Processing Record 46 of Set 5 | sao filipe
# Processing Record 47 of Set 5 | upernavik
# Processing Record 48 of Set 5 | tetiz
# Processing Record 49 of Set 5 | east london
# Processing Record 50 of Set 5 | richards bay
# Processing Record 1 of Set 6 | imbituba
# Processing Record 2 of Set 6 | superior
# Processing Record 3 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 6 | tahe
# Processing Record 5 of Set 6 | abu dhabi
# Processing Record 6 of Set 6 | iranshahr
# Processing Record 7 of Set 6 | fairbanks
# Processing Record 8 of Set 6 | taltal
# Processing Record 9 of Set 6 | goderich
# Processing Record 10 of Set 6 | mishelevka
# Processing Record 11 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 12 of Set 6 | makakilo city
# Processing Record 13 of Set 6 | sandnessjoen
# Processing Record 14 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 6 | geraldton
# Processing Record 16 of Set 6 | moche
# Processing Record 17 of Set 6 | nanuque
# Processing Record 18 of Set 6 | hebertville
# City not found. Skipping...
# Processing Record 19 of Set 6 | clyde river
# Processing Record 20 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 21 of Set 6 | asfi
# Processing Record 22 of Set 6 | luanda
# Processing Record 23 of Set 6 | katsuura
# Processing Record 24 of Set 6 | winton
# Processing Record 25 of Set 6 | luebo
# Processing Record 26 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 27 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 6 | kruisfontein
# Processing Record 29 of Set 6 | dourbali
# Processing Record 30 of Set 6 | alberton
# Processing Record 31 of Set 6 | san patricio
# Processing Record 32 of Set 6 | sinnamary
# Processing Record 33 of Set 6 | ongandjera
# Processing Record 34 of Set 6 | brae
# Processing Record 35 of Set 6 | iwaki
# Processing Record 36 of Set 6 | antofagasta
# Processing Record 37 of Set 6 | hay river
# Processing Record 38 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 6 | linjiang
# Processing Record 40 of Set 6 | bathsheba
# Processing Record 41 of Set 6 | longyearbyen
# Processing Record 42 of Set 6 | haines junction
# Processing Record 43 of Set 6 | adrar
# Processing Record 44 of Set 6 | surt
# Processing Record 45 of Set 6 | spornoye
# Processing Record 46 of Set 6 | virginia beach
# Processing Record 47 of Set 6 | westport
# Processing Record 48 of Set 6 | ola
# Processing Record 49 of Set 6 | moberly
# Processing Record 50 of Set 6 | adre
# Processing Record 1 of Set 7 | mount gambier
# Processing Record 2 of Set 7 | marsa matruh
# Processing Record 3 of Set 7 | benghazi
# Processing Record 4 of Set 7 | hofn
# Processing Record 5 of Set 7 | kyra
# Processing Record 6 of Set 7 | kavaratti
# Processing Record 7 of Set 7 | yaan
# Processing Record 8 of Set 7 | temaraia
# City not found. Skipping...
# Processing Record 9 of Set 7 | mecca
# Processing Record 10 of Set 7 | sorland
# Processing Record 11 of Set 7 | maniitsoq
# Processing Record 12 of Set 7 | kalmunai
# Processing Record 13 of Set 7 | kahului
# Processing Record 14 of Set 7 | lebu
# Processing Record 15 of Set 7 | russell
# Processing Record 16 of Set 7 | almaznyy
# Processing Record 17 of Set 7 | mosjoen
# Processing Record 18 of Set 7 | mar del plata
# Processing Record 19 of Set 7 | athabasca
# Processing Record 20 of Set 7 | taseyevo
# Processing Record 21 of Set 7 | kenai
# Processing Record 22 of Set 7 | tilichiki
# Processing Record 23 of Set 7 | handwara
# City not found. Skipping...
# Processing Record 24 of Set 7 | dembi dolo
# Processing Record 25 of Set 7 | manggar
# Processing Record 26 of Set 7 | university place
# Processing Record 27 of Set 7 | rocha
# Processing Record 28 of Set 7 | ulladulla
# Processing Record 29 of Set 7 | egvekinot
# Processing Record 30 of Set 7 | uglegorsk
# Processing Record 31 of Set 7 | si sa ket
# Processing Record 32 of Set 7 | ilulissat
# Processing Record 33 of Set 7 | kota kinabalu
# Processing Record 34 of Set 7 | acapulco
# Processing Record 35 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 36 of Set 7 | namatanai
# Processing Record 37 of Set 7 | akdagmadeni
# Processing Record 38 of Set 7 | chengde
# Processing Record 39 of Set 7 | capao da canoa
# Processing Record 40 of Set 7 | okha
# Processing Record 41 of Set 7 | mahajanga
# Processing Record 42 of Set 7 | emerald
# Processing Record 43 of Set 7 | buri
# Processing Record 44 of Set 7 | half moon bay
# Processing Record 45 of Set 7 | alofi
# Processing Record 46 of Set 7 | waipawa
# Processing Record 47 of Set 7 | labuhan
# Processing Record 48 of Set 7 | jizan
# Processing Record 49 of Set 7 | olinda
# Processing Record 50 of Set 7 | fort frances
# Processing Record 1 of Set 8 | marathon
# Processing Record 2 of Set 8 | platonovka
# Processing Record 3 of Set 8 | pemangkat
# Processing Record 4 of Set 8 | sechura
# Processing Record 5 of Set 8 | karoi
# Processing Record 6 of Set 8 | anju
# Processing Record 7 of Set 8 | puerto escondido
# Processing Record 8 of Set 8 | avera
# Processing Record 9 of Set 8 | tenkodogo
# Processing Record 10 of Set 8 | trifos
# City not found. Skipping...
# Processing Record 11 of Set 8 | saint george
# Processing Record 12 of Set 8 | dipkarpaz
# City not found. Skipping...
# Processing Record 13 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 14 of Set 8 | peterborough
# Processing Record 15 of Set 8 | chaman
# Processing Record 16 of Set 8 | mayumba
# Processing Record 17 of Set 8 | turan
# Processing Record 18 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 19 of Set 8 | karauzyak
# City not found. Skipping...
# Processing Record 20 of Set 8 | yuncheng
# Processing Record 21 of Set 8 | quang ngai
# Processing Record 22 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 23 of Set 8 | richland
# Processing Record 24 of Set 8 | sanming
# Processing Record 25 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 26 of Set 8 | alihe
# Processing Record 27 of Set 8 | saryshagan
# City not found. Skipping...
# Processing Record 28 of Set 8 | sitka
# Processing Record 29 of Set 8 | sao jose da coroa grande
# Processing Record 30 of Set 8 | kiunga
# Processing Record 31 of Set 8 | neepawa
# Processing Record 32 of Set 8 | tuatapere
# Processing Record 33 of Set 8 | high level
# Processing Record 34 of Set 8 | teya
# Processing Record 35 of Set 8 | piacabucu
# Processing Record 36 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 8 | ferme-neuve
# Processing Record 38 of Set 8 | gilazi
# City not found. Skipping...
# Processing Record 39 of Set 8 | scottsburgh
# City not found. Skipping...
# Processing Record 40 of Set 8 | maceio
# Processing Record 41 of Set 8 | belyy yar
# Processing Record 42 of Set 8 | almeirim
# Processing Record 43 of Set 8 | atbasar
# Processing Record 44 of Set 8 | cidreira
# Processing Record 45 of Set 8 | ternate
# Processing Record 46 of Set 8 | kodinsk
# Processing Record 47 of Set 8 | talnakh
# Processing Record 48 of Set 8 | pacific grove
# Processing Record 49 of Set 8 | morgan city
# Processing Record 50 of Set 8 | chapais
# Processing Record 1 of Set 9 | merauke
# Processing Record 2 of Set 9 | tottenham
# Processing Record 3 of Set 9 | de aar
# Processing Record 4 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 5 of Set 9 | lagoa
# Processing Record 6 of Set 9 | malakal
# Processing Record 7 of Set 9 | kaitangata
# Processing Record 8 of Set 9 | ketchikan
# Processing Record 9 of Set 9 | galesong
# Processing Record 10 of Set 9 | esna
# Processing Record 11 of Set 9 | touros
# Processing Record 12 of Set 9 | cananeia
# Processing Record 13 of Set 9 | bacuit
# City not found. Skipping...
# Processing Record 14 of Set 9 | besenyszog
# Processing Record 15 of Set 9 | margate
# Processing Record 16 of Set 9 | dhari
# Processing Record 17 of Set 9 | basco
# Processing Record 18 of Set 9 | teguise
# Processing Record 19 of Set 9 | cheuskiny
# City not found. Skipping...
# Processing Record 20 of Set 9 | san jeronimo
# Processing Record 21 of Set 9 | naron
# Processing Record 22 of Set 9 | mhlambanyatsi
# Processing Record 23 of Set 9 | cockburn harbour
# City not found. Skipping...
# Processing Record 24 of Set 9 | alghero
# Processing Record 25 of Set 9 | krasnoselkup
# Processing Record 26 of Set 9 | ahipara
# Processing Record 27 of Set 9 | drumheller
# Processing Record 28 of Set 9 | nabire
# Processing Record 29 of Set 9 | muisne
# Processing Record 30 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 9 | ito
# Processing Record 32 of Set 9 | codrington
# Processing Record 33 of Set 9 | bengkulu
# Processing Record 34 of Set 9 | cherskiy
# Processing Record 35 of Set 9 | dicabisagan
# Processing Record 36 of Set 9 | nadym
# Processing Record 37 of Set 9 | arlit
# Processing Record 38 of Set 9 | beloha
# Processing Record 39 of Set 9 | bela
# Processing Record 40 of Set 9 | wewak
# Processing Record 41 of Set 9 | falealupo
# City not found. Skipping...
# Processing Record 42 of Set 9 | seymour
# Processing Record 43 of Set 9 | saint-georges
# Processing Record 44 of Set 9 | panaba
# Processing Record 45 of Set 9 | sarangani
# Processing Record 46 of Set 9 | dwarka
# Processing Record 47 of Set 9 | melendugno
# Processing Record 48 of Set 9 | havoysund
# Processing Record 49 of Set 9 | neiafu
# Processing Record 50 of Set 9 | constitucion
# Processing Record 1 of Set 10 | dumai
# Processing Record 2 of Set 10 | loukhi
# Processing Record 3 of Set 10 | bilibino
# Processing Record 4 of Set 10 | na wa
# Processing Record 5 of Set 10 | kuvshinovo
# Processing Record 6 of Set 10 | manzhouli
# Processing Record 7 of Set 10 | naze
# Processing Record 8 of Set 10 | ukwa
# Processing Record 9 of Set 10 | wanxian
# Processing Record 10 of Set 10 | nouadhibou
# Processing Record 11 of Set 10 | corner brook
# Processing Record 12 of Set 10 | hunucma
# Processing Record 13 of Set 10 | cabedelo
# Processing Record 14 of Set 10 | mareeba
# Processing Record 15 of Set 10 | rabo de peixe
# Processing Record 16 of Set 10 | taiyuan
# Processing Record 17 of Set 10 | peniche
# Processing Record 18 of Set 10 | oksfjord
# Processing Record 19 of Set 10 | wuda
# Processing Record 20 of Set 10 | kytlym
# City not found. Skipping...
# Processing Record 21 of Set 10 | ye
# City not found. Skipping...
# Processing Record 22 of Set 10 | moron
# Processing Record 23 of Set 10 | barabai
# Processing Record 24 of Set 10 | paredon
# Processing Record 25 of Set 10 | mahadday weyne
# City not found. Skipping...
# Processing Record 26 of Set 10 | dubai
# Processing Record 27 of Set 10 | sapiranga
# Processing Record 28 of Set 10 | harlingen
# Processing Record 29 of Set 10 | trinidad
# Processing Record 30 of Set 10 | seydi
# Processing Record 31 of Set 10 | ullapool
# Processing Record 32 of Set 10 | songea
# Processing Record 33 of Set 10 | san cristobal
# Processing Record 34 of Set 10 | victoria point
# Processing Record 35 of Set 10 | canavieiras
# Processing Record 36 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 37 of Set 10 | presidencia roque saenz pena
# Processing Record 38 of Set 10 | cordoba
# Processing Record 39 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 40 of Set 10 | matara
# Processing Record 41 of Set 10 | kommunisticheskiy
# Processing Record 42 of Set 10 | aklavik
# Processing Record 43 of Set 10 | onega
# Processing Record 44 of Set 10 | hualmay
# Processing Record 45 of Set 10 | dzhebariki-khaya
# Processing Record 46 of Set 10 | libreville
# Processing Record 47 of Set 10 | faanui
# Processing Record 48 of Set 10 | bilma
# Processing Record 49 of Set 10 | vila velha
# Processing Record 50 of Set 10 | chipinge
# Processing Record 1 of Set 11 | marystown
# Processing Record 2 of Set 11 | raga
# Processing Record 3 of Set 11 | yabelo
# Processing Record 4 of Set 11 | tecoanapa
# Processing Record 5 of Set 11 | blackwater
# Processing Record 6 of Set 11 | jalingo
# Processing Record 7 of Set 11 | barybino
# Processing Record 8 of Set 11 | oistins
# Processing Record 9 of Set 11 | mullaitivu
# City not found. Skipping...
# Processing Record 10 of Set 11 | coahuayana
# Processing Record 11 of Set 11 | anchorage
# Processing Record 12 of Set 11 | hanna
# Processing Record 13 of Set 11 | umea
# Processing Record 14 of Set 11 | henties bay
# Processing Record 15 of Set 11 | rudbar
# Processing Record 16 of Set 11 | hasaki
# Processing Record 17 of Set 11 | zhuhai
# Processing Record 18 of Set 11 | comodoro rivadavia
# Processing Record 19 of Set 11 | redmond
# Processing Record 20 of Set 11 | atar
# Processing Record 21 of Set 11 | labrea
# Processing Record 22 of Set 11 | shakawe
# Processing Record 23 of Set 11 | vanavara
# Processing Record 24 of Set 11 | velingara
# Processing Record 25 of Set 11 | kupang
# Processing Record 26 of Set 11 | keti bandar
# Processing Record 27 of Set 11 | pangnirtung
# Processing Record 28 of Set 11 | general pico
# Processing Record 29 of Set 11 | agadir
# Processing Record 30 of Set 11 | argelia
# Processing Record 31 of Set 11 | kirakira
# Processing Record 32 of Set 11 | poya
# Processing Record 33 of Set 11 | carinhanha
# Processing Record 34 of Set 11 | uren
# Processing Record 35 of Set 11 | ponta do sol
# Processing Record 36 of Set 11 | baoro
# Processing Record 37 of Set 11 | puchezh
# Processing Record 38 of Set 11 | soure
# Processing Record 39 of Set 11 | san quintin
# Processing Record 40 of Set 11 | bereda
# Processing Record 41 of Set 11 | necochea
# Processing Record 42 of Set 11 | marsh harbour
# Processing Record 43 of Set 11 | luwuk
# Processing Record 44 of Set 11 | chabahar
# Processing Record 45 of Set 11 | tsienyane
# City not found. Skipping...
# Processing Record 46 of Set 11 | hammond
# Processing Record 47 of Set 11 | quincy
# Processing Record 48 of Set 11 | santa marta
# Processing Record 49 of Set 11 | pochutla
# Processing Record 50 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 1 of Set 12 | vardo
# Processing Record 2 of Set 12 | rosarito
# Processing Record 3 of Set 12 | batesville
# Processing Record 4 of Set 12 | marquette
# Processing Record 5 of Set 12 | iqaluit
# Processing Record 6 of Set 12 | rockhampton
# Processing Record 7 of Set 12 | bubaque
# Processing Record 8 of Set 12 | chimbote
# Processing Record 9 of Set 12 | bobrovka
# Processing Record 10 of Set 12 | korla
# Processing Record 11 of Set 12 | gangotri
# City not found. Skipping...
# Processing Record 12 of Set 12 | bulgan
# Processing Record 13 of Set 12 | am timan
# Processing Record 14 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 15 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 16 of Set 12 | ulaangom
# Processing Record 17 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 12 | raudeberg
# Processing Record 19 of Set 12 | helong
# Processing Record 20 of Set 12 | rorvik
# Processing Record 21 of Set 12 | willmar
# Processing Record 22 of Set 12 | escarcega
# Processing Record 23 of Set 12 | darnah
# Processing Record 24 of Set 12 | banyuwangi
# Processing Record 25 of Set 12 | dzemul
# Processing Record 26 of Set 12 | tabuk
# Processing Record 27 of Set 12 | udachnyy
# Processing Record 28 of Set 12 | matamoros
# Processing Record 29 of Set 12 | devils lake
# Processing Record 30 of Set 12 | aviles
# Processing Record 31 of Set 12 | baykit
# Processing Record 32 of Set 12 | rio gallegos
# Processing Record 33 of Set 12 | el faiyum
# City not found. Skipping...
# Processing Record 34 of Set 12 | tautira
# Processing Record 35 of Set 12 | hita
# Processing Record 36 of Set 12 | manacapuru
# Processing Record 37 of Set 12 | knysna
# Processing Record 38 of Set 12 | cap malheureux
# Processing Record 39 of Set 12 | colares
# Processing Record 40 of Set 12 | puertollano
# Processing Record 41 of Set 12 | tura
# Processing Record 42 of Set 12 | axim
# Processing Record 43 of Set 12 | constantine
# Processing Record 44 of Set 12 | austin
# Processing Record 45 of Set 12 | det udom
# Processing Record 46 of Set 12 | gland
# Processing Record 47 of Set 12 | carbonia
# Processing Record 48 of Set 12 | lethem
# Processing Record 49 of Set 12 | gat
# Processing Record 50 of Set 12 | perth
# Processing Record 1 of Set 13 | graaff-reinet
# Processing Record 2 of Set 13 | miyako
# Processing Record 3 of Set 13 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 4 of Set 13 | makat
# Processing Record 5 of Set 13 | cam ranh
# Processing Record 6 of Set 13 | tottori
# Processing Record 7 of Set 13 | banepa
# Processing Record 8 of Set 13 | broomall
# Processing Record 9 of Set 13 | marion
# Processing Record 10 of Set 13 | kakching
# Processing Record 11 of Set 13 | fethiye
# Processing Record 12 of Set 13 | port moresby
# Processing Record 13 of Set 13 | yashan
# Processing Record 14 of Set 13 | alta floresta
# Processing Record 15 of Set 13 | karratha
# Processing Record 16 of Set 13 | kashi
# Processing Record 17 of Set 13 | chumikan
# Processing Record 18 of Set 13 | conceicao do araguaia
# Processing Record 19 of Set 13 | chicama
# Processing Record 20 of Set 13 | singaraja
# Processing Record 21 of Set 13 | santa catarina de tepehuanes
# Processing Record 22 of Set 13 | rawson
# Processing Record 23 of Set 13 | zatoka
# Processing Record 24 of Set 13 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 13 | nsanje
# Processing Record 26 of Set 13 | katangli
# Processing Record 27 of Set 13 | montoro
# Processing Record 28 of Set 13 | aranos
# Processing Record 29 of Set 13 | sembe
# Processing Record 30 of Set 13 | vagur
# Processing Record 31 of Set 13 | auki
# Processing Record 32 of Set 13 | burnie
# Processing Record 33 of Set 13 | fiumicino
# Processing Record 34 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 35 of Set 13 | orotukan
# Processing Record 36 of Set 13 | qasigiannguit
# Processing Record 37 of Set 13 | hobyo
# Processing Record 38 of Set 13 | bandar-e lengeh
# Processing Record 39 of Set 13 | el alto
# Processing Record 40 of Set 13 | tambovka
# Processing Record 41 of Set 13 | canutama
# Processing Record 42 of Set 13 | najran
# Processing Record 43 of Set 13 | hvide sande
# Processing Record 44 of Set 13 | telbang
# Processing Record 45 of Set 13 | yatou
# Processing Record 46 of Set 13 | fairmont
# Processing Record 47 of Set 13 | berbera
# Processing Record 48 of Set 13 | aksu
# Processing Record 49 of Set 13 | winnemucca
# Processing Record 50 of Set 13 | tungao
# Processing Record 1 of Set 14 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 2 of Set 14 | tromso
# Processing Record 3 of Set 14 | sao luiz gonzaga
# Processing Record 4 of Set 14 | port-cartier
# Processing Record 5 of Set 14 | barcelona
# Processing Record 6 of Set 14 | tiznit
# Processing Record 7 of Set 14 | kota tinggi
# Processing Record 8 of Set 14 | misratah
# Processing Record 9 of Set 14 | nara
# Processing Record 10 of Set 14 | porto novo
# Processing Record 11 of Set 14 | grand gaube
# Processing Record 12 of Set 14 | bonthe
# Processing Record 13 of Set 14 | safwah
# City not found. Skipping...
# Processing Record 14 of Set 14 | santa maria
# Processing Record 15 of Set 14 | jumla
# Processing Record 16 of Set 14 | bafoulabe
# Processing Record 17 of Set 14 | nizhniy tsasuchey
# Processing Record 18 of Set 14 | jackson
# Processing Record 19 of Set 14 | chontalpa
# Processing Record 20 of Set 14 | lasa
# Processing Record 21 of Set 14 | urucurituba
# Processing Record 22 of Set 14 | carlyle
# Processing Record 23 of Set 14 | tidore
# City not found. Skipping...
# Processing Record 24 of Set 14 | muravlenko
# Processing Record 25 of Set 14 | adeje
# Processing Record 26 of Set 14 | santiago de cuba
# Processing Record 27 of Set 14 | mogadishu
# Processing Record 28 of Set 14 | the valley
# Processing Record 29 of Set 14 | severo-yeniseyskiy
# Processing Record 30 of Set 14 | kingman
# Processing Record 31 of Set 14 | oyama
# Processing Record 32 of Set 14 | byron bay
# Processing Record 33 of Set 14 | buluang
# Processing Record 34 of Set 14 | xadani
# City not found. Skipping...
# Processing Record 35 of Set 14 | road town
# Processing Record 36 of Set 14 | kosh-agach
# Processing Record 37 of Set 14 | stege
# Processing Record 38 of Set 14 | andrews
# Processing Record 39 of Set 14 | afsin
# Processing Record 40 of Set 14 | pionerskiy
# Processing Record 41 of Set 14 | samana
# Processing Record 42 of Set 14 | amuntai
# Processing Record 43 of Set 14 | altamira
# Processing Record 44 of Set 14 | flin flon
# Processing Record 45 of Set 14 | porto velho
# Processing Record 46 of Set 14 | calabozo
# Processing Record 47 of Set 14 | coolum beach
# Processing Record 48 of Set 14 | durazno
# Processing Record 49 of Set 14 | kamaishi
# Processing Record 50 of Set 14 | san miguel
# Processing Record 1 of Set 15 | aksha
# Processing Record 2 of Set 15 | martapura
# Processing Record 3 of Set 15 | tlahualilo
# City not found. Skipping...
# Processing Record 4 of Set 15 | nemuro
# Processing Record 5 of Set 15 | urfa
# City not found. Skipping...
# Processing Record 6 of Set 15 | bratsk
# Processing Record 7 of Set 15 | te anau
# Processing Record 8 of Set 15 | asau
# Processing Record 9 of Set 15 | sinjar
# Processing Record 10 of Set 15 | abalak
# Processing Record 11 of Set 15 | dunedin
# Processing Record 12 of Set 15 | aberdeen
# Processing Record 13 of Set 15 | urusha
# Processing Record 14 of Set 15 | herat
# Processing Record 15 of Set 15 | stromness
# Processing Record 16 of Set 15 | yagodnoye
# Processing Record 17 of Set 15 | grand-lahou
# Processing Record 18 of Set 15 | varzea alegre
# Processing Record 19 of Set 15 | port keats
# Processing Record 20 of Set 15 | weihe
# Processing Record 21 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 22 of Set 15 | novyy urengoy
# Processing Record 23 of Set 15 | satipo
# Processing Record 24 of Set 15 | fortuna
# Processing Record 25 of Set 15 | port lincoln
# Processing Record 26 of Set 15 | umarkhed
# Processing Record 27 of Set 15 | santa ana
# Processing Record 28 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 29 of Set 15 | quatre cocos
# Processing Record 30 of Set 15 | banda aceh
# Processing Record 31 of Set 15 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 32 of Set 15 | huamachuco
# Processing Record 33 of Set 15 | petrova
# Processing Record 34 of Set 15 | sierra vista
# Processing Record 35 of Set 15 | san antonio
# Processing Record 36 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 37 of Set 15 | alugan
# Processing Record 38 of Set 15 | walvis bay
# Processing Record 39 of Set 15 | itaqui
# Processing Record 40 of Set 15 | college
# Processing Record 41 of Set 15 | tra vinh
# Processing Record 42 of Set 15 | evensk
# Processing Record 43 of Set 15 | shaunavon
# Processing Record 44 of Set 15 | lokosovo
# Processing Record 45 of Set 15 | tevriz
# Processing Record 46 of Set 15 | iberia
# Processing Record 47 of Set 15 | umm lajj
# Processing Record 48 of Set 15 | tessalit
# Processing Record 49 of Set 15 | kaputa
# Processing Record 50 of Set 15 | tondano
# Processing Record 1 of Set 16 | zelenoborskiy
# Processing Record 2 of Set 16 | srivardhan
# Processing Record 3 of Set 16 | karkaralinsk
# City not found. Skipping...
# Processing Record 4 of Set 16 | ilorin
# Processing Record 5 of Set 16 | montague
# Processing Record 6 of Set 16 | turbat
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#       City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Hilo      US  19.7297 -155.0900     80.33        71          20
# 1   Vanimo      PG  -2.6741  141.3028     77.13        90          67
# 2    Kimbe      PG  -5.5502  150.1429     74.23        92          11
# 3  Ruidoso      US  33.3317 -105.6730     63.10        94          90
# 4  Qaanaaq      GL  77.4840  -69.3632     40.23        98         100
#
#    Wind Speed Current Description
# 0        9.22          light rain
# 1        6.82       broken clouds
# 2        3.85          few clouds
# 3       11.50     overcast clouds
# 4        4.88          light rain

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
